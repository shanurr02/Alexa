# %% [markdown]
# <a href="https://colab.research.google.com/github/shanurr02/Alexa/blob/main/StockMarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import http.client

conn = http.client.HTTPSConnection("share-market-news-api-india.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "240f57949amsh8a48bd030ba07d0p19baf0jsn9f9347d8522a",
    'X-RapidAPI-Host': "share-market-news-api-india.p.rapidapi.com"
}

conn.request("GET", "/marketNews", headers=headers)

res = conn.getresponse()
data = res.read()
news = data.decode("utf-8")

print(data.decode("utf-8"))
# Out:
# [{"Title":"Trading Holidays","URL":"https://www.bseindia.com//static/markets/marketinfo/listholi.aspx","Source":"BSE India"},{"Title":"Registered Investors","URL":"https://www.bseindia.com//markets/keystatics/KeyStat_ClientStat.aspx?expandable =4","Source":"BSE India"},{"Title":"IPOs/FPOs","URL":"https://economictimes.indiatimes.com/markets/ipo","Source":"Economics Times Market"},{"Title":"ChartMantra Technicals Trading Game","URL":"https://chartmantra.economictimes.indiatimes.com/GameBoard.htm","Source":"Economics Times Market"},{"Title":"Is the worst behind them? 5 stocks from electrical and mini white good space with upside potential of up to 42%","URL":"https://economictimes.indiatimes.com/markets/stocks/news/is-the-worst-behind-them-5-stocks-from-electrical-and-mini-white-good-space-with-upside-potential-of-up-to-42/articleshow/108072535.cms","Source":"Economics Times Market"},{"Title":"Taking, understanding and managing risks are three different things: 5 smallcap stocks from different sectors","URL":"https://economictimes.indiatimes.com/markets/stocks/news/taking-understanding-and-managing-risks-are-three-different-things-5-smallcap-stocks-from-different-sectors/articleshow/108069114.cms","Source":"Economics Times Market"},{"Title":"Defence stock aims for 8% rise even as realty player eyes 6% appreciation","URL":"https://economictimes.indiatimes.com/markets/stocks/news/defence-stock-aims-for-8-rise-even-as-realty-player-eyes-6-appreciation/articleshow/108067174.cms","Source":"Economics Times Market"},{"Title":"Fundamental Radar I Why does Piramal Pharma stock deserve a re-rating? Sandeep Raina explains","URL":"https://economictimes.indiatimes.com/markets/stocks/news/fundamental-radar-i-why-does-piramal-pharma-stock-deserve-a-re-rating-sandeep-raina-explains/videoshow/108016721.cms","Source":"Economics Times Market"},{"Title":"Record $277-billion rally! Nvidia's single-day surge is more than Reliance's total market value","URL":"https://economictimes.indiatimes.com/markets/stocks/news/record-277-billion-rally-nvidias-single-day-surge-is-more-than-reliances-total-market-value/videoshow/107947734.cms","Source":"Economics Times Market"},{"Title":"Mukka Proteins raises Rs 67 from anchor investors ahead of IPO","URL":"https://economictimes.indiatimes.com/markets/ipos/fpos/mukka-proteins-raises-rs-67-from-anchor-investors-ahead-of-ipo/articleshow/108081248.cms","Source":"Economics Times Market"},{"Title":"Market Trading Guide: Tech Mahindra, Havells among 4 stock recommendations for Thursday","URL":"https://economictimes.indiatimes.com/markets/stocks/news/market-trading-guide-tech-mahindra-havells-among-4-stock-recommendations-for-thursday/slideshow/108081066.cms","Source":"Economics Times Market"},{"Title":"ET Market Watch: 6 factors behind today's market crash that led to erosion of 6L Cr from D-street","URL":"https://economictimes.indiatimes.com/markets/stocks/etmarkets-podcast/et-market-watch-6-factors-behind-todays-market-crash-that-led-to-erosion-of-6l-cr-from-d-street/podcast/108081022.cms","Source":"Economics Times Market"},{"Title":"Shriram Finance to replace UPL in Nifty50 from March 28","URL":"https://economictimes.indiatimes.com/markets/stocks/news/shriram-finance-to-replace-upl-in-nifty50-from-march-28/articleshow/108080350.cms","Source":"Economics Times Market"},{"Title":"Top 8 stock ideas by Prabhudas Lilladher with up to 26% upside scope","URL":"https://economictimes.indiatimes.com/markets/stocks/news/top-8-stock-ideas-by-prabhudas-lilladher-with-up-to-26-upside-scope/slideshow/108077544.cms","Source":"Economics Times Market"},{"Title":"These 5 capital goods stocks hit a 52-week high and rallied up to 15% in a month","URL":"https://economictimes.indiatimes.com/markets/web-stories/these-5-capital-goods-stocks-hit-a-52-week-high-and-rallied-up-to-15-in-a-month/slideshow/108076364.cms","Source":"Economics Times Market"},{"Title":"Indian Hotels among 4 stocks with top long unwinding","URL":"https://economictimes.in ...

# %%
import pandas as pd

df = pd.read_csv("IndianFinancialNews.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   50000 non-null  int64
#  1   Date         50000 non-null  object
#  2   Title        50000 non-null  object
#  3   Description  49290 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.5+ MB

# %%
df.head()
# Out:
#    Unnamed: 0                    Date  \
# 0           0   May 26, 2020, Tuesday
# 1           1   May 26, 2020, Tuesday
# 2           2    May 25, 2020, Monday
# 3           3    May 24, 2020, Sunday
# 4           4  May 23, 2020, Saturday
#
#                                                Title  \
# 0  ATMs to become virtual bank branches, accept d...
# 1  IDFC First Bank seniors to forgo 65% of bonus ...
# 2  Huge scam in YES Bank for many years, says Enf...
# 3  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4  DCB Bank's profit before tax declines 37.6% to...
#
#                                          Description
# 0  Close to 14.6 per cent (or 35,000) of the 240,...
# 1  V Vaidyanathan, managing director and chief ex...
# 2  Rana Kapoor's wife also charged with abetting ...
# 3  The bank said it was now gearing up to extend ...
# 4  Net profit for the financial year ended March ...

# %%
df.tail()
# Out:
#        Unnamed: 0                        Date  \
# 49995       49995  February 11, 2003, Tuesday
# 49996       49996  February 11, 2003, Tuesday
# 49997       49997   February 10, 2003, Monday
# 49998       49998   February 10, 2003, Monday
# 49999       49999   February 10, 2003, Monday
#
#                                                    Title  \
# 49995  Lic Mops Up Government Securities As Prices Crash
# 49996  Banks Plan To Raise Lending Rates Without Alte...
# 49997          Net Scheduled Inflows Of Rs 1,559.9 Crore
# 49998      Rbi Calls Meet To Push Floating Rate Deposits
# 49999                    Sticky Loans Divide Consortiums
#
#                                              Description
# 49995  Lic Mops Up Government Securities As Prices Crash
# 49996  Banks Plan To Raise Lending Rates Without Alte...
# 49997          Net Scheduled Inflows Of Rs 1,559.9 Crore
# 49998      Rbi Calls Meet To Push Floating Rate Deposits
# 49999                    Sticky Loans Divide Consortiums

# %%
df.flags
# Out:
# <Flags(allows_duplicate_labels=True)>

# %%
# !pip install nltk
# !python -m nltk.downloader vader_lexicon
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

sma = SentimentIntensityAnalyzer()

def get_sentiment_score(text):
    return sma.polarity_scores(text)['compound']

df['Description'] = df['Description'].astype(str)
df['sentiment_score'] = df['Description'].apply(get_sentiment_score)


def categorize_sentiment(score):
    if score >= 0.05:
        return 'positive'
    elif score <= -0.05:
        return 'negative'
    else:
        return 'neutral'

df['sentiment_category'] = df['sentiment_score'].apply(categorize_sentiment)

# Step 6: Review Results
dataframe = df[['Date', 'Title', 'Description', 'sentiment_category']]
dataframe.head()
# Out:
#                      Date                                              Title  \
# 0   May 26, 2020, Tuesday  ATMs to become virtual bank branches, accept d...
# 1   May 26, 2020, Tuesday  IDFC First Bank seniors to forgo 65% of bonus ...
# 2    May 25, 2020, Monday  Huge scam in YES Bank for many years, says Enf...
# 3    May 24, 2020, Sunday  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4  May 23, 2020, Saturday  DCB Bank's profit before tax declines 37.6% to...
#
#                                          Description sentiment_category
# 0  Close to 14.6 per cent (or 35,000) of the 240,...            neutral
# 1  V Vaidyanathan, managing director and chief ex...           negative
# 2  Rana Kapoor's wife also charged with abetting ...           negative
# 3  The bank said it was now gearing up to extend ...           positive
# 4  Net profit for the financial year ended March ...           positive

# %%
dataframe.head()
# Out:
#                      Date                                              Title  \
# 0   May 26, 2020, Tuesday  ATMs to become virtual bank branches, accept d...
# 1   May 26, 2020, Tuesday  IDFC First Bank seniors to forgo 65% of bonus ...
# 2    May 25, 2020, Monday  Huge scam in YES Bank for many years, says Enf...
# 3    May 24, 2020, Sunday  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4  May 23, 2020, Saturday  DCB Bank's profit before tax declines 37.6% to...
#
#                                          Description sentiment_category
# 0  Close to 14.6 per cent (or 35,000) of the 240,...            neutral
# 1  V Vaidyanathan, managing director and chief ex...           negative
# 2  Rana Kapoor's wife also charged with abetting ...           negative
# 3  The bank said it was now gearing up to extend ...           positive
# 4  Net profit for the financial year ended March ...           positive

# %%
dataframe.to_csv('IndianFinancialNewsWithSentiment.csv', index=False)
